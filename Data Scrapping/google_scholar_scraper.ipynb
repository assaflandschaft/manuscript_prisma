# %% [markdown]
# ## Installs/ Imports

# %%
# !pip install BeautifulSoup4
# Out:
# Requirement already satisfied: BeautifulSoup4 in /usr/local/lib/python3.10/dist-packages (4.11.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from BeautifulSoup4) (2.5)

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
from requests.adapters import HTTPAdapter
from requests.packages.urllib3.util.retry import Retry

# %% [markdown]
# ## Data Scraping
#
# The code below is responsible for scraping Google Scholars for responses to the query "patient trial matching". We retrieve the rank, title, hyperlink and partial abstract of the first 1000 articles. The requests are sent and processed in batches of 10 articles with timeouts and retries if the server is non-responsive. The responses for each batch are parsed, processed and saved in `google_scholar_patient_trial_matching_data.csv`.

# %%
def write_csv_file(data_list):
    """ Function used to save the scraped data from `data_list` to a csv file, namely
    `google_scholar_patient_trial_matching_data.csv`. The information is appended to
    the end of the csv file.
    """
    # Convert the list of dictionaries to a pandas DataFrame
    df = pd.DataFrame(data_list)
    # Specify the file path where you want to save the CSV file
    file_path = "google_scholar_patient_trial_matching_data.csv"
    # Save the DataFrame to a CSV file
    df.to_csv(file_path, index=False)
    print(f"Data has been appended to '{file_path}' in CSV format.")

# %% [markdown]
# The function below is designed to manage retries in case the server encounters non-responsive behavior or returns various status codes. Additionally, in the event of receiving a 429 status code, it incorporates a delay mechanism that gradually increases if a 200 response is not achieved. This iterative delay strategy persists until the maximum number of retry attempts is reached.

# %%
def send_request_with_retries(req_url, max_retries, headers, payload):
    """ Sends the requests for a batch of articles until either the request is successful (status code 200),
    in which case it returns the response from server, or until `max_retries` is reached, in which case it
    prints out an errror message and returns None. In case of an unsuccessful request, sets progressively
    longer delays before the next request.
    """
    # Create a session
    session = requests.Session()
    # Configure retries
    retries = Retry(total=max_retries, backoff_factor=0.1, status_forcelist=[500, 502, 503, 504])
    # Mount the adapter with retries to the session
    session.mount("https://", HTTPAdapter(max_retries=retries))
    try:
        response = session.get(req_url, headers=headers, data=payload)
        # Check if the request was successful (HTTP status code 200)
        if response.status_code == 200:
            return response
        else:
            # ADDED MORE RETRIES IF STATUS CODE IS 429 WITH DELAY
            retry_attempts = 0
            while retry_attempts < max_retries:
                response = session.get(req_url, headers=headers, data=payload)
                if response.status_code == 429 or response.status_code == 403:
                    # Retry after waiting with exponential backoff
                    wait_time = 2 ** retry_attempts  # Wait for 2^retry_attempts seconds
                    time.sleep(wait_time)
                    retry_attempts += 1
                elif response.status_code == 200:
                    return response
                else:
                    break
            print(f"Request failed with status code {response.status_code}")
            return None
    except requests.exceptions.RequestException as e:
        print(f"Request error: {e}")
        return None

# %% [markdown]
# The get_search_data() function efficiently conducts searches across multiple pages (performing peginated search 1 by 1), performs data scraping, and meticulously compiles the required information. The resulting dataset is then meticulously saved to a CSV file for comprehensive data management and analysis

# %%
def get_search_data():
    """ Function that fetches, parses and saves the data from the top 1000 articles appearing in response to
    a "patient trial matching" search on Google Scholar.
    """
    meta_data = []
    rank_value = 1
    page_count = 1
    response = requests.get(url="https://scholar.google.com/scholar?hl=en&as_sdt=0%2C5&q=patient+trial+matching&btnG=")
    cookies = response.cookies
    # Initialize an empty string to store the concatenated cookies
    concatenated_cookies = ""
    # Iterate through the cookies and concatenate their names and values
    for cookie in cookies:
        concatenated_cookies += f"{cookie.name}={cookie.value}; "
    # Remove the trailing semicolon and space
    concatenated_cookies = concatenated_cookies.rstrip("; ")
    for i in range(0, 1020, 10):
        # I am handling pagination here, loop will start from 0 and stop at 1000 by the increment of 10 at each
        # iteration
        search_url = f"https://scholar.google.de/scholar?start={i}&q=patient+trial+matching&hl=de&as_sdt=0,5"
        payload = {}
        headers = {
            'authority': 'scholar.google.de',
            'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
            'accept-language': 'en-US,en;q=0.9',
            'cookie': concatenated_cookies,
            'referer': f'https://scholar.google.de/scholar?hl=de&as_sdt={i - 10}%2C5&q=patient+trial+matching&btnG=',
            'sec-ch-ua': '"Not.A/Brand";v="8", "Chromium";v="114", "Google Chrome";v="114"',
            'sec-ch-ua-mobile': '?0',
            'sec-ch-ua-platform': '"Windows"',
            'sec-fetch-dest': 'document',
            'sec-fetch-mode': 'navigate',
            'sec-fetch-site': 'same-origin',
            'sec-fetch-user': '?1',
            'upgrade-insecure-requests': '1',
            'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36',
            'x-client-data': 'CJW2yQEIorbJAQipncoBCNr5ygEIkqHLAQiFoM0BCIinzQEI3L3NAQjgxM0BCLnKzQEIuM3NAQiTz80B'
        }
        max_retries = 5
        # adding delay in necessary when you want to send many requests to a server
        time.sleep(4)  # you can increase it ( like 6 seconds or more) just in case if you receive 429 or 403 status
        response = send_request_with_retries(search_url, max_retries, headers, payload)

        if response:
            # Assuming 'html' contains the HTML content of the webpage
            soup = BeautifulSoup(response.text, 'html.parser')
            # getting all tags containing titles
            titles = soup.find_all(class_='gs_rt')
            abstracts = soup.find_all(class_='gs_rs')
            for i in range(0, len(titles)):
                item = dict()
                item["Rank"] = rank_value
                # increment rank value for each record
                rank_value = rank_value + 1
                # Find the element by its class and I am cleaning it to make sure there's no Unicode characters
                item["Title"] = titles[i].findChild(name='a').get_text().strip().encode('ascii', 'ignore').decode('ascii') if titles[i].findChild(name='a') else titles[
                    i].findChild(name='a')
                item["Link"] = titles[i].findChild(name='a')['href'] if titles[i].findChild(name='a') else titles[
                    i].findChild(name='a')
                item["Abstract"] = abstracts[i].get_text().strip().encode('ascii', 'ignore').decode('ascii').strip().replace("\n", "")
                meta_data.append(item)
                print(item)
        print(f"********************* {page_count}-PAGE SCRAPED !! *********************")
        if meta_data:
            write_csv_file(meta_data)
        page_count = page_count + 1

# %%
get_search_data()
# Out:
# {'Rank': 1, 'Title': 'Project MATCH: Rationale and methods for a multisite clinical trial matching patients to alcoholism treatment', 'Link': 'https://ohsu.elsevierpure.com/en/publications/project-match-rationale-and-methods-for-a-multisite-clinical-tria-2', 'Abstract': 'Interaction effects with selected patient characteristics will be studied. Project MATCH will provide a rigorous test of the utility of patient-treatment matching in general and, depending on'}
# {'Rank': 2, 'Title': 'DeepEnroll: patient-trial matching with deep embedding and entailment prediction', 'Link': 'https://dl.acm.org/doi/abs/10.1145/3366423.3380181', 'Abstract': 'We evaluated DeepEnroll on both real world clinical trial dataset and a synthetic data. We evaluated the patient-trial matching via predicting patient enrollment for trials. DeepEnroll'}
# {'Rank': 3, 'Title': 'COMPOSE: Cross-modal pseudo-siamese network for patient trial matching', 'Link': 'https://dl.acm.org/doi/abs/10.1145/3394486.3403123', 'Abstract': 'To enable the patienttrial matching task, we also learn effective patient representation from patient data (eg, EHR) by using memory network. In this work, we developed a hierarchical'}
# {'Rank': 4, 'Title': 'Evaluation of an artificial intelligence clinical trial matching system in Australian lung cancer patients', 'Link': 'https://academic.oup.com/jamiaopen/article-abstract/3/2/209/5827849', 'Abstract': '(per patient median 74, range 53100) against 11 467 individual trial eligibility criteria (per trial  On a per-patient basis, the performance of the trial matching system for eligibility was as'}
# {'Rank': 5, 'Title': 'Automated classification of eligibility criteria in clinical trials to facilitate patient-trial matching for specific patient populations', 'Link': 'https://academic.oup.com/jamia/article-abstract/24/4/781/3038205', 'Abstract': 'for patient-trial matching and  matching systems, eg, those by Ni et al., 11 , 12 Sahoo et al., 13 and Miotto and Weng, 14 rely on data from clinical trial records and individual patient data'}
# {'Rank': 6, 'Title': 'User-centered research on breast cancer patient needs and preferences of an Internet-based clinical trial matching system', 'Link': 'https://www.jmir.org/2007/2/e13/UR', 'Abstract': 'Background: Internet-based clinical trial matching systems have the potential to  patients perceive and interact with a preliminary version of an Internet-based clinical trial matching'}
# {'Rank': 7, 'Title': 'Impact of a cognitive computing clinical trial matching system in an ambulatory oncology practice.', 'Link': 'https://ascopubs.org/doi/abs/10.1200/JCO.2018.36.15_suppl.6550', 'Abstract': 'Systemic therapy trials enrolling breast cancer patients were  trial matches on the day prior to patient clinic visits. They gave the oncology providers a list of matched trials for each patient'}
# {'Rank': 8, 'Title': 'Clinical performance pilot using cognitive computing for clinical trial matching at Mayo Clinic.', 'Link': 'https://ascopubs.org/doi/abs/10.1200/JCO.2018.36.15_suppl.e18598', 'Abstract': 'Using trial eligibility criteria and filters for patient setting (metastatic vs. non- patients as potentially eligible or ineligible for each protocol. Time to complete this review per patient was'}
# {'Rank': 9, 'Title': 'Overcoming barriers to clinical trial participation: Outcomes of a national clinical trial matching and navigation service for patients with a blood cancer', 'Link': 'https://ascopubs.org/doi/abs/10.1200/OP.20.01068', 'Abstract': 'a free, national clinical trial matching and nurse navigation service for patients with a  patients with closed cases, the clinical trial enrollment rate was 16.1%. Among those who had a trial'}
# {'Rank': 10, 'Title': 'Outcomes of a cancer clinical trial matching service', 'Link': 'https://link.springer.com/article/10.1007/s13187-011-0296-x', 'Abstract': '(approximately triple the national average), based on our available data, we cannot determine the extent to which the CTMS motivated patients to ask their physicians about other trial'}
# ********************* 1-PAGE SCRAPED !! *********************
# Data has been appended to 'google_scholar_patient_trial_matching_data.csv' in CSV format.
# {'Rank': 11, 'Title': 'Learnings from precision clinical trial matching for oncology patients who received NGS testing', 'Link': 'https://ascopubs.org/doi/abs/10.1200/CCI.20.00142', 'Abstract': 'trial matching at the Vanderbilt-Ingram Cancer Center (VICC), an NCI-designated Comprehensive Cancer Center in Nashville, TN. Augmented trial matching  clinical trial matching study'}
# {'Rank': 12, 'Title': 'Towards Fair Patient-Trial Matching via Patient-Criterion Level Fairness Constraint', 'Link': 'https://arxiv.org/abs/2303.13790', 'Abstract': 'Patient-Trial matching: We define the patient-trial matching task as a binary classification  a patient P is qualified for a clinical trial C. A patient P is considered eligible for a clinical trial C'}
# {'Rank': 13, 'Title': 'Neural query synthesis and domain-specific ranking templates for multi-stage clinical trial matching', 'Link': 'https://dl.acm.org/doi/pdf/10.1145/3477495.3531853', 'Abstract': 'the patients who miss out on the potential health benefits from such clinical interventions.  trial matching problem we consider can be described as such: Given a patient and the patients'}
# {'Rank': 14, 'Title': 'TREEMENT: Interpretable Patient-Trial Matching via Personalized Dynamic Tree-Based Memory Network', 'Link': 'https://arxiv.org/abs/2307.09942', 'Abstract': 'depend on trial-specific expert rules that cannot expand to other trials or perform matching at a  To provide accurate and interpretable patient trial matching, we introduce a personalized'}
# {'Rank': 15, 'Title': 'Cognitive technology addressing optimal cancer clinical trial matching and protocol feasibility in a community cancer practice.', 'Link': 'https://ascopubs.org/doi/abs/10.1200/jco.2017.35.15_suppl.6501', 'Abstract': 'the clinical trial matching process. This solution helps providers locate suitable protocols for  patients by reading the trial criteria and matching it to the structured and unstructured patient'}
# {'Rank': 16, 'Title': 'clinical trial recruitment: a protocol for the development and preliminary testing of an online prostate cancer health information and clinical trial matching tool', 'Link': 'https://pilotfeasibilitystudies.biomedcentral.com/articles/10.1186/s40814-019-0516-4', 'Abstract': 'Trial Library is designed to be an Internet-based cancer clinical trial matching tool that enables patients to view information about prostate cancer clinical trials for which they may be'}
# {'Rank': 17, 'Title': 'Adoption, acceptability, and accuracy of an online clinical trial matching website for breast cancer', 'Link': 'https://www.jmir.org/2012/4/e97/', 'Abstract': 'Patients who wish to use this or other clinical trial matching websites should keep copies of their medical records so that they can enter a profile that will facilitate their gaining access to'}
# {'Rank': 18, 'Title': 'Integration of electronic pathology reporting with clinical trial matching for advanced prostate cancer', 'Link': 'https://www.sciencedirect.com/science/article/pii/S1078143920306396', 'Abstract': 'trial matching tool (called Trial Library) used in combination with e-path to improve matching of underrepresented patients  that clinical trial information is seldom accessed by patients.'}
# {'Rank': 19, 'Title': 'Implementation of artificial intelligence (AI) for lung cancer clinical trial matching in a tertiary cancer center', 'Link': 'https://www.annalsofoncology.org/article/S0923-7534(19)30153-X/abstract', 'Abstract': 'trial matches on the day prior to patient clinic visits. A list of matched trials for each patient was  Results: Watson for CTM facilitated screening of all lung cancer patients against 42 trials.'}
# {'Rank': 20, 'Title': 'Scaling Clinical Trial Matching Using Large Language Models: A Case Study in Oncology', 'Link': 'https://arxiv.org/abs/2308.02180', 'Abstract': 'amount of training data of known patient-trial matches (or patient-criteria matches) and their  trial eligibility criteria and Pstructured denote that of a patient. Then clinical trial matching'}
# ********************* 2-PAGE SCRAPED !! *********************
# Data has been appended to 'google_scholar_patient_trial_matching_data.csv' in CSV format.
# {'Rank': 21, 'Title': 'Analysis of not structurable oncological study eligibility criteria for improved patient-trial matching', 'Link': 'https://www.thieme-connect.com/products/ejournals/html/10.1055/s-0041-1724107', 'Abstract': 'Background Higher enrolment rates of cancer patients into  matching of patient characteristics with clinical trial eligibility  The necessity of a partially manual patient trial matching is'}
# {'Rank': 22, 'Title': 'Artificial intelligence for clinical trial design', 'Link': 'https://www.cell.com/trends/pharmacological-sciences/fulltext/S0165-6147(19)30130-0?dgcid=raven_jbs_etoc_email', 'Abstract': 'trial databases for improved patienttrial matching and recruitment before a trial starts, as well as for monitoring patients automatically and continuously during the trial, thereby allowing'}
# {'Rank': 23, 'Title': 'LLM for Patient-Trial Matching: Privacy-Aware Data Augmentation Towards Better Performance and Generalizability', 'Link': 'https://arxiv.org/abs/2303.16756', 'Abstract': 'Throughout the model optimization process, we aim to maximize patient-trial matching while explicitly addressing the differences between inclusion and exclusion criteria. To achieve'}
# {'Rank': 24, 'Title': 'Patient trial matching using pseudo-siamese network.', 'Link': 'https://ascopubs.org/doi/abs/10.1200/JCO.2020.38.15_suppl.e14050', 'Abstract': 'for at least one trial. We compared our model with leading pt-trial matching models. Our model  We therefore propose a new pt-trial matching model based on Pseudo-Siamese network'}
# {'Rank': 25, 'Title': 'Increasing the efficiency of trial-patient matching: automated clinical trial eligibility pre-screening for pediatric oncology patients', 'Link': 'https://link.springer.com/article/10.1186/s12911-015-0149-3', 'Abstract': 'Without automation, an oncologist would need to review 42 trials per patient on average to replicate the patient-trial matches that occur in the retrospective data set. With automated ES'}
# {'Rank': 26, 'Title': 'Biomarker enrichment strategies: matching trial design to biomarker credentials', 'Link': 'https://www.nature.com/articles/nrclinonc.2013.218', 'Abstract': 'of biomarker-positive patients. This Review considers which clinical trial designs and analysis  that the biomarker can successfully identify patients who will respond to the treatment in'}
# {'Rank': 27, 'Title': "The impact of matching the patient's vocabulary: a randomized control trial", 'Link': 'https://academic.oup.com/fampra/article-abstract/21/6/630/508710', 'Abstract': 'and patients, 1 3 no studies have examined the impact of matched versus unmatched vocabulary on patient  the impact of matched and unmatched vocabulary on patient satisfaction. It'}
# {'Rank': 28, 'Title': 'Molecular profiling of advanced solid tumors and patient outcomes with genotype-matched clinical trials: the Princess Margaret IMPACT/COMPACT trial', 'Link': 'https://genomemedicine.biomedcentral.com/articles/10.1186/s13073-016-0364-2', 'Abstract': 'The clinical utility of molecular profiling of tumor tissue to guide treatment of patients with advanced solid tumors is unknown. Our objectives were to evaluate the frequency of genomic'}
# {'Rank': 29, 'Title': '312P ClinMatch: A clinical trial matching platform that improves trial accessibility among NSCLC patients through comprehensive genomic and clinical profiling', 'Link': 'https://www.annalsofoncology.org/article/S0923-7534(22)04532-X/abstract', 'Abstract': 'language processing algorithm that curates trial descriptions and patient records (2) A cloud  and fuzzy search of matching eligibility criteria. As a pilot study, patients with non-small cell'}
# {'Rank': 30, 'Title': 'Developments in alcoholism treatment research: Patient-treatment matching', 'Link': 'https://www.sciencedirect.com/science/article/pii/0741832994900698', 'Abstract': 'Treatment matching THE purpose of this article is to describe patient-treatment matching, a  methods for a multisite clinical trial matching alcoholism patients to treatment. Alcohol. Clin.'}
# ********************* 3-PAGE SCRAPED !! *********************
# Data has been appended to 'google_scholar_patient_trial_matching_data.csv' in CSV format.
# {'Rank': 31, 'Title': 'Digital ECMT Cancer Trial Matching Tool: an Open Source Research Application to Support Oncologists in the Identification of Precision Medicine Clinical Trials', 'Link': 'https://ascopubs.org/doi/abs/10.1200/CCI.22.00137', 'Abstract': 'However, the matching process  trial information to support oncologists in the matching process, and we illustrate its utility with recent case studies of patients who were matched to trials'}
# {'Rank': 32, 'Title': 'Mobile Clinical Trial Matching Technology in Medical Oncology Clinic: A Pilot Feasibility Study', 'Link': 'https://ascopubs.org/doi/abs/10.1200/CCI.21.00182', 'Abstract': 'online patient-facing intervention to promote clinical trial discussions  trial discussion during medical oncology visits for patients with advanced PCa and increased interest in clinical trial'}
# {'Rank': 33, 'Title': 'OncoCTMiner: streamlining precision oncology trial matching via molecular profile analysis', 'Link': 'https://www.medrxiv.org/content/10.1101/2023.07.10.23292477.abstract', 'Abstract': 'patient genetic data to trial eligibility criteria poses a significant challenge for physicians, who must  platform aims to offer an intuitive solution that enhances automated trial matching.'}
# {'Rank': 34, 'Title': 'Matching patient records to clinical trials using ontologies', 'Link': 'https://link.springer.com/chapter/10.1007/978-3-540-76298-0_59', 'Abstract': 'matching patients to clinical trials can be formulated as a problem of semantic retrieval, ie, a clinical trial  For the use of clinical trial matching, which is currently a manual process, our'}
# {'Rank': 35, 'Title': 'Trial prospector: matching patients with cancer research studies using an automated and scalable approach', 'Link': 'https://journals.sagepub.com/doi/abs/10.4137/CIN.S19454', 'Abstract': 'for individual patients. We introduce the Trial Prospector tool that supports end-to-end management of cancer clinical trial recruitment workflow with (a) structured entry of trial eligibility'}
# {'Rank': 36, 'Title': 'Review of the Performance Metrics for Natural Language Systems for Clinical Trials Matching', 'Link': 'https://ebooks.iospress.nl/doi/10.3233/SHTI220156', 'Abstract': 'In this study, the evaluation methods of clinical trial matching systems are investigated for their definitions of gold-standard. This study urges the need for a gold standard in the patient'}
# {'Rank': 37, 'Title': 'Improving disease named entity recognition for clinical trial matching', 'Link': 'https://ieeexplore.ieee.org/abstract/document/8983421/', 'Abstract': 'as clinical trial matching, patient profiling,  trial texts have unique complexities compared to patient-centric clinical reports or biomedical research articles, as they typically define patient'}
# {'Rank': 38, 'Title': 'Improving Data Quality in an Institutional Clinical Trial Data Repository to Support Patient-Trial Matching', 'Link': 'https://jscholarship.library.jhu.edu/handle/1774.2/67315', 'Abstract': 'unstructured aggregated institutional clinical trial summaries with their  trial texts belonging to the same trial (matches) and those belonging to different trials (mismatches), using trial'}
# {'Rank': 39, 'Title': 'A pilot study to implement an artificial intelligence (AI) system for gastrointestinal cancer clinical trial matching', 'Link': 'https://www.sciencedirect.com/science/article/pii/S0923753419596430', 'Abstract': 'Patients were evaluated against 50 GI-specific drug therapy and multi-disease phase I  trial matching using CTM took an average of 10.1 minutes (Range: 4 to 20 min) per patient'}
# {'Rank': 40, 'Title': 'Matching patients and practitioners based on beliefs about care: results of a randomized controlled trial', 'Link': 'http://ajmc.s3.amazonaws.com/_media/_pdf/AJMC_04novKrupat814to22.pdf', 'Abstract': 'arm generated better matches on patient-practitioner beliefs than Usual Care; however, trust and satisfaction were higher among Guided Choice patients. Across study arms, patient-'}
# ********************* 4-PAGE SCRAPED !! *********************
# Data has been appended to 'google_scholar_patient_trial_matching_data.csv' in CSV format.
# {'Rank': 41, 'Title': 'Prospective RBC phenotype matching in a strokeprevention trial in sickle cell anemia: a multicenter transfusion trial', 'Link': 'https://onlinelibrary.wiley.com/doi/abs/10.1046/j.1537-2995.2001.41091086.x', 'Abstract': 'of the recipientdonor population was a factor in the development of alloimmunization among SCD patients, we determined the RBC phenotypes of 125 patients (Table 2). Five'}
# {'Rank': 42, 'Title': 'Cost-effectiveness potential of a clinical trial matching application in cancer care', 'Link': 'https://aaltodoc.aalto.fi/handle/123456789/109389', 'Abstract': 'This study focuses on the trial matching of patients with acute myeloid leukemia (AML). AML is a serious disease in need of new treatments, and there are many trials evaluating new'}
# {'Rank': 43, 'Title': 'MatchMiner: An open-source AI precision medicine trial matching platform', 'Link': 'https://aacrjournals.org/cancerres/article/83/7_Supplement/1067/721619', 'Abstract': 'patients who are more likely to be ready to enroll onto a trial. By using NLP to filter trial matches, we  s efficiency of finding trial matches and provide more timely trial options for patients.'}
# {'Rank': 44, 'Title': 'MatchMiner: An open source computational platform for real-time matching of cancer patients to precision medicine clinical trials using genomic and clinical criteria', 'Link': 'https://www.biorxiv.org/content/10.1101/199489.abstract', 'Abstract': 'Results To meet these needs, we built and deployed an automated clinical trial matching platform called MatchMiner at the Dana-Farber Cancer Institute (DFCI). The platform has been'}
# {'Rank': 45, 'Title': 'Automated Matching of Patients to Clinical Trials: A Patient-Centric Natural Language Processing Approach for Pediatric Leukemia', 'Link': 'https://ascopubs.org/doi/abs/10.1200/CCI.23.00009', 'Abstract': 'To our knowledge, this project represents the first open-source attempt to generate a patient-centric clinical trial matching tool. The tool demonstrated acceptable performance when'}
# {'Rank': 46, 'Title': 'AI for Healthcare: Diagnosis, Clinical-Trial Matching, and Patient Recruitment', 'Link': 'https://oaktrust.library.tamu.edu/handle/1969.1/192242', 'Abstract': '2.2 Clinical-Trial Matching We are trying to explore how clinical trials for various patients can be matched with the right treatments. There has been active research in the domain of'}
# {'Rank': 47, 'Title': 'Learnings from a pragmatic study to evaluate benefit of performing reflex clinical trial matching and providing clinical decision support to physicians.', 'Link': 'https://ascopubs.org/doi/abs/10.1200/JCO.2019.37.15_suppl.e18006', 'Abstract': 'trial matching can kick-start the process without requiring human intervention. Methods: Using a clinical trial matching  to perform reflex clinical trial matching on oncology patients. A'}
# {'Rank': 48, 'Title': 'Effect of matching therapists to patients vs assignment as usual on adult psychotherapy outcomes: a randomized clinical trial', 'Link': 'https://jamanetwork.com/journals/jamapsychiatry/article-abstract/2780658', 'Abstract': 'of patient-therapist matching with an individual-level, double-blind, randomized clinical trial within a community MHC system. Adult outpatients were randomly assigned to matching or'}
# {'Rank': 49, 'Title': 'A Hybrid Approach to Precision Medicine-related Biomedical Article Retrieval and Clinical Trial Matching.', 'Link': 'https://openreview.net/pdf?id=JYUWmPqFD89', 'Abstract': 'We build a hybrid system to retrieve and match treatment-related biomedical articles and clinical trials to eligible patients based on a strict rule matching approach and an ontology-'}
# {'Rank': 50, 'Title': '1933MO TransFAL: Establishment of clinical trial-matched luminal breast cancer patient-derived xenografts (PDX) for translational studies', 'Link': 'https://www.annalsofoncology.org/article/S0923-7534(20)41322-5/abstract', 'Abstract': 'Background PARSIFAL was a randomized phase II trial aimed at evaluating the efficacy of palbociclib (P) plus either fulvestrant (F) or letrozole (L) in Estrogen Receptor [+]/Human'}
# ********************* 5-PAGE SCRAPED !! *********************
# Data has been appended to 'google_scholar_patient_trial_matching_data.csv' in CSV format.
# {'Rank': 51, 'Title': 'Matching Patients to Clinical Trials with Large Language Models', 'Link': 'https://arxiv.org/abs/2307.15051', 'Abstract': 'three publicly available patient-trial matching datasets, where the patients are represented  However, clinical trial matching in real life often requires the recruiters to check the patients'}
# {'Rank': 52, 'Title': 'Simulating patient matching to clinical trials using a property rights blockchain', 'Link': 'https://journals.lww.com/dm/Fulltext/2020/06010/Simulating_patient_matching_to_clinical_trials.8.aspx', 'Abstract': 'Trial matching services review the patient blockchain records and recommend study participants that are likely to meet the enrollment criteria of recruiting clinical trials. Digital'}
# {'Rank': 53, 'Title': 'OA10. 03 How LungMATCH, A Personalized Treatment Navigation and Clinical Trial Matching Service, Affects the Treatment Journey', 'Link': 'https://www.jto.org/article/S1556-0864(21)02489-8/abstract', 'Abstract': 'treatment navigation and clinical trial matching. The program gives patients and caregivers access to  and nation-wide clinical trial searches and matching in addition to free educational'}
# {'Rank': 54, 'Title': 'A phase I/II dose-escalation trial of vitamin D3 and calcium in multiple sclerosis', 'Link': 'https://n.neurology.org/content/74/23/1852.short', 'Abstract': 'trial matched patients with MS for demographic and disease characteristics, with randomization to treatment or control groups. Treatment patients  was given throughout the trial. Primary'}
# {'Rank': 55, 'Title': 'Fox Trial Finder: An Innovative Web-Based Trial Matching Tool To Facilitate Clinical Trial Recruitment (P02. 241)', 'Link': 'https://n.neurology.org/content/78/1_Supplement/P02.241.short', 'Abstract': 'trial recruitment: 1) Patient  PD patients had participated in a trial. (This survey is being repeated; results will be available for presentation at the meeting.) Existing online PD clinical trial'}
# {'Rank': 56, 'Title': 'Impella support for acute myocardial infarction complicated by cardiogenic shock: matched-pair iabp-shock II trial 30-day mortality analysis', 'Link': 'https://www.ahajournals.org/doi/abs/10.1161/CIRCULATIONAHA.118.036614', 'Abstract': 'All patients underwent early  II) trial inclusion and exclusion criteria, 372 patients were identified and included in this analysis. These patients were matched to 600 patients from the IABP'}
# {'Rank': 57, 'Title': 'Abstract P5-07-01: BreastCancerTrials. org: Early Evaluation of a Nationwide Clinical Trial Matching Service', 'Link': 'https://aacrjournals.org/cancerres/article/70/24_Supplement/P5-07-01/560565', 'Abstract': 'that breast cancer patients were willing to use an online clinical trial matching service, that  led to valid matches. In a companion study to evaluate the accuracy of patient-entered data,'}
# {'Rank': 58, 'Title': 'Initial results of a new clinical trial matching service to increase patient participation', 'Link': 'https://ascopubs.org/doi/abs/10.1200/jco.2009.27.15_suppl.e17504', 'Abstract': 'e17504 Methods: Data from CTMS constituents and follow-up information describing enrollment status and barriers to trial participation are reviewed. Results: During 15 months of'}
# {'Rank': 59, 'Title': 'A prospective, multicenter, phase I matched-comparison group trial of safety, pharmacokinetics, and preliminary efficacy of riluzole in patients with traumatic spinal', 'Link': 'https://www.liebertpub.com/doi/abs/10.1089/neu.2013.2969', 'Abstract': 'matched patients in the NACTN SCI Registry. Medical complications in riluzole-treated patients occurred with incidences similar to those in patients  patients for different enzymes. Three'}
# {'Rank': 60, 'Title': 'A matched-pair cluster-randomized trial of guided care for high-risk older patients', 'Link': 'https://link.springer.com/article/10.1007/s11606-012-2287-y', 'Abstract': 'During 20062009, we conducted a matched-pair, cluster-randomized controlled trial of Guided Care versus usual care in eight community-based primary care practices operated by'}
# ********************* 6-PAGE SCRAPED !! *********************
# Data has been appended to 'google_scholar_patient_trial_matching_data.csv' in CSV format.
# {'Rank': 61, 'Title': 'Matching patients with alcohol disorders to treatments: Clinical implications from Project MATCH', 'Link': 'https://www.tandfonline.com/doi/abs/10.1080/09638239817743', 'Abstract': 'trial, tested the matching hypothesis that alcoholism treatment outcomes can be improved by matching subgroups of patients  multisite clinical trial matching patients to alcoholism treat-'}
# {'Rank': 62, 'Title': 'Assessing patient trial readiness for precision cancer medicine clinical trials through computational trial matching and rule-based logic applied to genomic and clinical', 'Link': 'https://aacrjournals.org/cancerres/article-abstract/78/13_Supplement/2288/626562', 'Abstract': 'of potential patient-trial matches is performed.  patient-trial matches are computed across all open trials, which are then computationally filtered to a list of ~300 patient-trial matches'}
# {'Rank': 63, 'Title': 'Outcomes are not different for patient-matched versus nonmatched treatment in subjects with chronic recurrent low back pain: a randomized clinical trial', 'Link': 'https://www.sciencedirect.com/science/article/pii/S1529943014002988', 'Abstract': 'outcomes for patients with chronic LBP who were either matched or  We hypothesized that patients who were matched to  compared with patients who were not matched to treatment.'}
# {'Rank': 64, 'Title': 'Prognosis of patients with nonST-segmentelevation myocardial infarction and nonobstructive coronary artery disease: propensity-matched analysis from the acute', 'Link': 'https://www.ahajournals.org/doi/abs/10.1161/circinterventions.113.000606', 'Abstract': 'selected a patient with nonobstructive CAD and then matched that patient with 3 patients in  To assess the success of the matching procedure, we evaluated standardized differences of'}
# {'Rank': 65, 'Title': 'Impact of yoga on blood pressure and quality of life in patients with hypertensiona controlled trial in primary care, matched for systolic blood pressure', 'Link': 'https://link.springer.com/article/10.1186/1471-2261-13-111', 'Abstract': 'At baseline, the patients underwent standardized blood pressure measurement at the health  of the patients (92%) were on antihypertensive medication, and the patients were requested'}
# {'Rank': 66, 'Title': 'Accelerated clinical discovery using self-reported patient data collected online and a patient-matching algorithm', 'Link': 'https://www.nature.com/articles/nbt.1837', 'Abstract': '-led study were announced before the first randomized control trial had started recruitment. ( with multiple sclerosis patients suggest some benefit from using a matching algorithm to'}
# {'Rank': 67, 'Title': 'MatchMiner: Computational matching of cancer patients to precision medicine clinical trials', 'Link': 'https://www.ejcancer.com/article/S0959-8049(20)31112-6/abstract', 'Abstract': '-genomic data for trial matching. Support for  trial information in a computable form and developed an open-source computational trial matching platform to support patient-specific trial'}
# {'Rank': 68, 'Title': 'Lack of evidence of increased mortality among patients with atrial fibrillation taking digoxin: findings from post hoc propensity-matched analysis of the AFFIRM trial', 'Link': 'https://academic.oup.com/eurheartj/article-abstract/34/20/1489/489962', 'Abstract': 'of balanced-matched cohort of 890 pairs of patients based on propensity  matched cohort of 137 pairs of patients based on 205 patients receiving new digoxin therapy and 1329 patients'}
# {'Rank': 69, 'Title': 'to decrease xerostomia in locally advanced oropharynx carcinoma: An economic evaluation alongside the ARTIX Randomized Clinical Trial matched to the French', 'Link': 'https://www.sciencedirect.com/science/article/pii/S0398762023001943', 'Abstract': 'five patients did not consent, two patients did not match with the SNDS, and seven patients  the first CEA based on a Randomized Clinical Trial matched to the SNDS. The feasibility on'}
# {'Rank': 70, 'Title': 'A081: Trial Library: A pilot study to examine feasibility, acceptability, and preliminary estimates of efficacy for an online clinical trial matching website on patient', 'Link': 'https://aacrjournals.org/cebp/article/29/6_Supplement_1/A081/230787', 'Abstract': 'trial matching tool. We hypothesize that use of the Internet-based  trial matching tool in clinic will increase the number of patient-initiated conversations with physicians about clinical trial'}
# ********************* 7-PAGE SCRAPED !! *********************
# Data has been appended to 'google_scholar_patient_trial_matching_data.csv' in CSV format.
# {'Rank': 71, 'Title': 'transplantation is less effective than conventional consolidation/maintenance chemotherapy in all patients: final results of the International ALL Trial (MRC UKALL XII', 'Link': 'https://ashpublications.org/blood/article-abstract/111/4/1827/133215', 'Abstract': 'All patients who had an HLA-matched sibling donor were assigned to receive an allogeneic transplant. Patients with the Philadelphia chromosome could also receive a matched'}
# {'Rank': 72, 'Title': 'technique on circulating tumor cells and survival in patients with nonsmall cell lung cancer: a randomized clinical trial and registry-based propensity score matching', 'Link': 'https://jamanetwork.com/journals/jamasurgery/article-abstract/2732431', 'Abstract': 'Findings In this randomized clinical trial of 86 patients  65% of patients in the artery-first group and 31.6% of patients in the  cancerspecific survival for the patients in the vein-first group'}
# {'Rank': 73, 'Title': 'Medical versus surgical ICU obese patient outcome: a propensity-matched analysis to resolve clinical trial controversies', 'Link': 'https://www.ingentaconnect.com/content/wk/ccm/2018/00000046/00000004/art00003', 'Abstract': ', using a propensity scorematched analysis of patients with medical or surgical admission.  surgical obese patients, before and after matching. Before matching, medical patients had a'}
# {'Rank': 74, 'Title': 'First results from a propensity matching trial of mycophenolate mofetil vs. azathioprine in treatment-naive AIH patients', 'Link': 'https://www.frontiersin.org/articles/10.3389/fimmu.2021.798602/full', 'Abstract': 'of response in AIH patients (4). Accordingly, since 2016, we conducted a propensity matching trial of MMF vs. AZA administration in consecutive treatment-naive AIH patients in order to'}
# {'Rank': 75, 'Title': ', phase III clinical trial of antiT-lymphocyte globulin to assess impact on chronic graft-versus-host diseasefree survival in patients undergoing HLA-matched', 'Link': 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8462523/', 'Abstract': 'GVHD prophylaxis for patients who undergo myeloablative HLA-matched unrelated donor  We thank all the patients and their families for participating in this trial as well as the clinical'}
# {'Rank': 76, 'Title': 'American Cancer Society (ACS) clinical trial matching service (CTMS)', 'Link': 'https://ascopubs.org/doi/abs/10.1200/jco.2006.24.18_suppl.18501', 'Abstract': 'lung cancer patients requesting trial information had more advanced disease than typical patients in the National Cancer Database ( 2 , p < 0.001). Enrollment rates for patients with'}
# {'Rank': 77, 'Title': 'Evaluation of patient satisfaction and shade matching of Vita Suprinity versus lithium disilicate (E-max) ceramic crowns in the esthetic zone: a randomized', 'Link': 'https://f1000research.com/articles/8-371', 'Abstract': 'and patients as several studies concluded that patients were  assess patient satisfaction combined with shade matching of  Methods: 26 patients with teeth problems indicated for full'}
# {'Rank': 78, 'Title': 'Abstract LB-104: Clinical actionability and clinical trial matching for GENIE patient genotypes using My Cancer Genome, Personalized Cancer Therapy, and OncoKB', 'Link': 'https://aacrjournals.org/cancerres/article/77/13_Supplement/LB-104/622436', 'Abstract': 'For the expanded trial set, patients with non-small cell lung cancer, colorectal  a trial. We will show how genetic testing panel size affects trial matching and present clinical trial matching'}
# {'Rank': 79, 'Title': 'I37 Hd trialfinder: a clinical trial matching resource for the HD community', 'Link': 'https://jnnp.bmj.com/content/87/suppl_1/a71.3.abstract', 'Abstract': 'riers to trial participation. Aim HDSA identified the lack of a patient friendly, reliable clinical trial  The web-based portion is a free, easy-to-use clinical trial matching program that connects'}
# {'Rank': 80, 'Title': 'Validation of a software-based clinical trial matching platform for oncology using comprehensive clinical information.', 'Link': 'https://ascopubs.org/doi/abs/10.1200/JCO.2018.36.15_suppl.e18589', 'Abstract': 'trials fail to recruit enough patients to meet their statistical  clinical trial eligibility screening for individual cancer patients and  patients who were enrolled on a therapeutic clinical trial at'}
# ********************* 8-PAGE SCRAPED !! *********************
# Data has been appended to 'google_scholar_patient_trial_matching_data.csv' in CSV format.
# {'Rank': 81, 'Title': 'The effect of chairside verbal instructions matched with instagram social media on oral hygiene of young orthodontic patients: a randomized clinical trial', 'Link': 'https://www.mdpi.com/2076-3417/11/2/706', 'Abstract': 'In addition, multimedia contents on Instagram were sent weekly to trial  Trial patients demonstrated significant improvements in  towards young patients under an orthodontic treatment.'}
# {'Rank': 82, 'Title': 'Identifying subgroups of patients with acute/subacute nonspecific low back pain: results of a randomized clinical trial', 'Link': 'https://journals.lww.com/spinejournal/fulltext/2006/03150/Identifying_Subgroups_of_Patients_With.4.aspx', 'Abstract': 'We further examined the impact of receiving matched treatment by comparing the proportions of patients progressing to Stage II treatment, and the number of treatment sessions'}
# {'Rank': 83, 'Title': 'Stage-matched intervention for adherence to CPAP in patients with obstructive sleep apnea: a randomized controlled trial', 'Link': 'https://link.springer.com/article/10.1007/s11325-012-0766-3', 'Abstract': 'to shed light on the stage-matched intervention which is easy to  patients with OSAS in China. In this study, a 3-month stage-matched intervention had a favorable influence on patients'}
# {'Rank': 84, 'Title': 'Stepped care vs. matched care for mood and anxiety disorders: a randomized trial in routine practice', 'Link': 'https://onlinelibrary.wiley.com/doi/abs/10.1111/j.1600-0447.2005.00731.x', 'Abstract': 'Therefore, we conclude that patients do not necessarily benefit more from matched care with more intensive treatments than from stepped care with a low intensity treatment as a first'}
# {'Rank': 85, 'Title': 'An algorithm for prospective individual matching in a non-randomized clinical trial', 'Link': 'https://www.sciencedirect.com/science/article/pii/S0895435601003997', 'Abstract': 'intervention floor patients were successfully matched to control floor patients. Excellent  in our trial was accomplished by individually matching each intervention patient to a patient'}
# {'Rank': 86, 'Title': 'Effects of digoxin at low serum concentrations on mortality and hospitalization in heart failure: a propensity-matched study of the DIG trial', 'Link': 'https://www.sciencedirect.com/science/article/pii/S0167527307002872', 'Abstract': 'To achieve balance in baseline covariates, we matched all 982 low SDC patients to 982 unique patients in the placebo group, who had very similar propensities for low SDC (Fig. 1) [24]'}
# {'Rank': 87, 'Title': 'Patient-to-treatment matching', 'Link': 'http://ndl.ethernet.edu.et/bitstream/123456789/11912/1/286.pdf#page=387', 'Abstract': 'patient-treatment matching is reviewed in this chapter. The primary emphasis is on the results of Project MATCH, a multisite US trial of patient-treatment matching  trial matching patients'}
# {'Rank': 88, 'Title': 'No difference in clinical outcome between patient-matched positioning guides and conventional instrumented total knee arthroplasty two years post', 'Link': 'https://boneandjoint.org.uk/article/10.1302/0301-620X.98B7.37274', 'Abstract': 'The surgeon enrolling patients in the trial was unaware of the type of treatment that patients would receive. The patients were also blinded to the method of alignment of the components'}
# {'Rank': 89, 'Title': 'System in patients undergoing transcatheter aortic valve replacement: the PROTECT-TAVI Trial (PROphylactic effecT of furosEmide-induCed diuresis with matched', 'Link': 'https://www.jacc.org/doi/abs/10.1016/j.jcin.2015.07.012', 'Abstract': 'strategy for AKI prevention in high-risk patients.  exactly matched to the volume of urine produced by the patient and precisely weighed by the system. The RenalGuard, with its matched'}
# {'Rank': 90, 'Title': 'corrective osteotomy for malunited fractures of the upper extremity using patient-matched instruments: a prospective, multicenter, open-label, single-arm trial', 'Link': 'https://journals.lww.com/jbjsjournal/FullText/2019/04170/Three_Dimensional_Corrective_Osteotomy_for.7.aspx', 'Abstract': ', and 3-D rapid prototyping technology has further enabled the manufacturing of patient-matched surgical guides and implants (patient-matched instruments, or PMIs). However, 3-D'}
# ********************* 9-PAGE SCRAPED !! *********************
# Data has been appended to 'google_scholar_patient_trial_matching_data.csv' in CSV format.
# {'Rank': 91, 'Title': 'Clinical trial emulation by matching time-dependent propensity scores: the example of estimating impact of kidney transplantation', 'Link': 'https://www.ingentaconnect.com/content/wk/ede/2020/00000032/00000002/art00012', 'Abstract': 'clinical trial, in which patients could not participate several times, we decided to perform the matching without replacement. This decision was also motivated by the fact that matching'}
# {'Rank': 92, 'Title': 'Safety and efficacy of fluvoxamine in COVID19 ICU patients: an open label, prospective cohort trial with matched controls', 'Link': 'https://bpspubs.onlinelibrary.wiley.com/doi/abs/10.1111/bcp.15126', 'Abstract': 'The study was designed as an open-label, prospective cohort trial with matched controls. The fluvoxamine patient cohort was prospectively matched for age, gender, vaccination against'}
# {'Rank': 93, 'Title': 'A randomized controlled trial of stagematched intervention for smoking cessation in cardiac outpatients', 'Link': 'https://onlinelibrary.wiley.com/doi/abs/10.1111/j.1360-0443.2011.03733.x', 'Abstract': "The individualized stage-matched smoking cessation counselling was developed based on  matched protocol was used to provide an appropriate intervention that matched the patient's"}
# {'Rank': 94, 'Title': 'and matched lymph node metastases-aspects on distribution and prognosis for patients with luminal A tumours: results from a prospective randomised trial', 'Link': 'https://link.springer.com/article/10.1186/1471-2407-13-558', 'Abstract': 'for patients alive and without metastases. The trial was approved by the Ethics committee at Lund University (LU240-01) and informed consent was obtained from all included patients.'}
# {'Rank': 95, 'Title': 'Propensity-matched comparisons of clinical outcomes after transapical or transfemoral transcatheter aortic valve replacement: a placement of aortic transcatheter', 'Link': 'https://www.ahajournals.org/doi/abs/10.1161/CIRCULATIONAHA.114.012525', 'Abstract': 'Therefore, using all as-treated PARTNER-I trial TAVR patients, including continuing access patients, we sought to identify differences in preprocedural characteristics of'}
# {'Rank': 96, 'Title': 'of a transtheoretical model-based exercise stage-matched intervention on exercise behavior in patients with coronary heart disease: a randomized controlled trial', 'Link': 'https://www.sciencedirect.com/science/article/pii/S0738399114001293', 'Abstract': 'This was a three-group, repeated measures, randomized controlled trial. A total of 196 eligible patients were recruited and the patients at each stage were randomly allocated to one of'}
# {'Rank': 97, 'Title': 'Matching optimal pacemaker to patient: do we need a large scale clinical trial of pacemaker mode selection?', 'Link': 'https://europepmc.org/article/med/8539151', 'Abstract': 'Matching optimal pacemaker to patient: do we need a large scale clinical trial of pacemaker mode selection?  A comment on this article appears in "Ethics of a'}
# {'Rank': 98, 'Title': 'Animal-assisted therapy and agitation and depression in nursing home residents with dementia: a matched casecontrol trial', 'Link': 'https://www.sciencedirect.com/science/article/pii/S1064748113001784', 'Abstract': 'Patients from the two groups were matched for age and  matched with the pretest total score of CMAI as the matching variable. After matching, 54 patients remained, with 27 matched'}
# {'Rank': 99, 'Title': 'for patients with uncomplicated acute appendicitis: A propensity scorematched analysis of patient-centered outcomes (the ACTUAA prospective multicenter trial)', 'Link': 'https://link.springer.com/article/10.1007/s00384-021-03843-8', 'Abstract': 'Of the 318 patients enrolled in the study, 27.4% underwent antibiotic-first therapy, and 72.6 The matched group was composed of 87 patients in both study arms. Of the 87 patients'}
# {'Rank': 100, 'Title': 'Genomic and transcriptomic profiling expands precision cancer medicine: the WINTHER trial', 'Link': 'https://www.nature.com/articles/s41591-019-0424-4', 'Abstract': 'trialWINTHERthat prospectively navigated patients to  The median PFS for patients with a high matching score and  ; the median PFS for patients with a low matching score or a'}
# ********************* 10-PAGE SCRAPED !! *********************
# Data has been appended to 'google_scholar_patient_trial_matching_data.csv' in CSV format.
# {'Rank': 101, 'Title': 'Myasthenia gravis is not an independent prognostic factor of thymoma: results of a propensity score matching trial of 470 patients', 'Link': 'https://www.frontiersin.org/articles/10.3389/fonc.2020.583489/full', 'Abstract': 'Differences in clinical characteristics and treatments between patients  matching trial to investigate whether MG is an independent prognostic predictor in thymoma. Methods: Patients'}
# {'Rank': 102, 'Title': 'Abstract IA4-1: Gene-based trial matching', 'Link': 'https://aacrjournals.org/clincancerres/article/16/14_Supplement/IA4-1/409', 'Abstract': 'for developing new trial approaches that may be faster, require fewer patients, and may  the right patients for the right trials through gene based trial matching. New approaches to trial'}
# {'Rank': 103, 'Title': 'with matched hydration: the MYTHOS (induced diuresis with matched hydration compared to standard hydration for contrast induced nephropathy prevention) trial', 'Link': 'https://www.jacc.org/doi/abs/10.1016/j.jcin.2011.08.017', 'Abstract': 'to a patient in an amount matched to the volume of urine produced by the patient, avoiding  patients were brought to the catheterization laboratory and underwent coronary angiography.'}
# {'Rank': 104, 'Title': 'Matching-adjusted indirect comparisons: a new tool for timely comparative effectiveness research', 'Link': 'https://www.sciencedirect.com/science/article/pii/S1098301512016105', 'Abstract': 'patients in one treatment group (in this case the trial with IPD) are weighted by their inverse odds of being in that group versus the other treatment group (in this case the trial  be matched'}
# {'Rank': 105, 'Title': 'Copy number evolution and its relationship with patient outcomean analysis of 178 matched presentation-relapse tumor pairs from the Myeloma XI trial', 'Link': 'https://www.nature.com/articles/s41375-020-01096-y', 'Abstract': 'Importantly, few studies have been performed on patients from a randomized clinical trial  ) in matched diagnosisrelapse tumor pairs in 178 UK NCRI Myeloma XI trial patients [17]. We'}
# {'Rank': 106, 'Title': 'The effect of visual scanning exercises integrated into physiotherapy in patients with unilateral spatial neglect poststroke: a matched-pair randomized control trial', 'Link': 'https://journals.sagepub.com/doi/abs/10.1177/1545968314526306', 'Abstract': 'A matched-pair randomized control trial was conducted. Subjects were matched according to their  All patients received task-specific activities for a 4-week intervention period. The'}
# {'Rank': 107, 'Title': 'Crestal bone stability around implants with horizontally matching connection after soft tissue thickening: a prospective clinical trial', 'Link': 'https://onlinelibrary.wiley.com/doi/abs/10.1111/cid.12155', 'Abstract': 'Individuals for this 1-year controlled clinical trial were selected among partially edentulous patients who attended Vilnius Implantology Center Clinic (Vilnius, Lithuania) for implant'}
# {'Rank': 108, 'Title': 'SYNERGY-AI: Artificial intelligence based precision oncology clinical trial matching and registry.', 'Link': 'https://ascopubs.org/doi/abs/10.1200/JCO.2019.37.4_suppl.TPS717', 'Abstract': 'Machine learning algorithms allow for dynamic matching based on CT allocation and availability for optimized matching. Patients voluntarily enroll into registry, which is non-'}
# {'Rank': 109, 'Title': 'A test collection for matching patients to clinical trials', 'Link': 'https://dl.acm.org/doi/abs/10.1145/2911451.2914672', 'Abstract': 'the use of search engines for matching eligible patients (the query) to  matched that criteria. Thus, Medtrack could be viewed as the opposite, trial-centric (trial is the query and patient'}
# {'Rank': 110, 'Title': 'Incidence of alloantibody formation after ABOD or extended matched red blood cell transfusions: a randomized trial (MATCH study)', 'Link': 'https://onlinelibrary.wiley.com/doi/abs/10.1111/trf.13347', 'Abstract': 'Extended matching seems successful only if the patient did  and patients will enable RBC matching for selected patients.  50% of randomized surgical patients were actually transfused'}
# ********************* 11-PAGE SCRAPED !! *********************
# Data has been appended to 'google_scholar_patient_trial_matching_data.csv' in CSV format.
# {'Rank': 111, 'Title': 'N2M2 (NOA-20) phase I/II trial of molecularly matched targeted therapies plus radiotherapy in patients with newly diagnosed non-MGMT hypermethylated', 'Link': 'https://academic.oup.com/neuro-oncology/article-abstract/21/1/95/5113425', 'Abstract': 'for patients with newly diagnosed isocitrate dehydrogenase (IDH) wildtype glioblastoma  to the best matching molecular alteration. Patients without matching alterations are randomized'}
# ...
# {'Rank': 850, 'Title': 'A randomized trial of amitriptyline and mexiletine for painful neuropathy in HIV infection', 'Link': 'https://n.neurology.org/content/51/6/1682.short', 'Abstract': 'Method: A randomized, double-blind, 10-week trial of 145 patients assigned equally to amitriptyline, mexiletine, or matching placebo. The primary outcome measure was the change in'}
# ********************* 85-PAGE SCRAPED !! *********************
# Data has been appended to 'google_scholar_patient_trial_matching_data.csv' in CSV format.
# {'Rank': 851, 'Title': 'Convalescent plasma treatment of severe COVID-19: a propensity scorematched control study', 'Link': 'https://www.nature.com/articles/s41591-020-1088-9', 'Abstract': 'matching was established, control patients were retrospectively chart reviewed by a medical data team who were blinded to information about the matched  , placebo-controlled trial. An'}
# {'Rank': 852, 'Title': 'SAT0142 MATCHING ADJUSTED INDIRECT COMPARISON OF FILGOTINIB VS. TOFACITINIB IN MODERATE-TO-SEVERE ACTIVE RHEUMATOID', 'Link': 'https://ard.bmj.com/content/79/Suppl_1/1009.abstract', 'Abstract': 'patient data (IPD) from one trial and aggregate data from the other to enable comparison of outcomes after matching  An anchored MAIC was conducted using IPD from the FINCH-1 trial'}
# {'Rank': 853, 'Title': 'Effects of early enteral nutrition on patients after emergency gastrointestinal surgery: a propensity score matching analysis', 'Link': 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4603119/', 'Abstract': 'method, we also generated comparison groups of patients who had similar factors that  randomized trial. However, although matching by propensity score creates a homogenous patient'}
# {'Rank': 854, 'Title': 'Special matching programs for kidney transplant patients with high PRA%', 'Link': 'https://journals.lww.com/transplantjournal/Fulltext/1999/04150/SPECIAL_MATCHING_PROGRAMS_FOR_KIDNEY_TRANSPLANT.591.aspx', 'Abstract': 'matching programs have been developed: the Highly Immunized Trial program (HIT) searches by trial  -A and B-antigens towards which the patients never formed antibodies. A suitable'}
# {'Rank': 855, 'Title': 'Trial Evaluating the Standardization of CD3+ T-Cell Dose for Patients Receiving Allogeneic Peripheral Blood Stem Cell Transplants (PBSCT) from Matched', 'Link': 'https://www.sciencedirect.com/science/article/pii/S1083879119316854', 'Abstract': 'We conducted a clinical trial of dose standardization of T-cells between December 2014  adult patients (pts) with hematologic malignancies undergoing peripheral blood matched sibling'}
# {'Rank': 856, 'Title': 'Matching-Adjusted Indirect Comparisons (MAICS) of Efficacy and Consumption of Bay 94-9027 Versus three Recombinant Factor VIII (RFVIII) for Prophylaxis of', 'Link': 'https://www.valueinhealthjournal.com/article/S1098-3015(18)31992-2/abstract', 'Abstract': 'using patient-level data from PROTECT-VIII trial for BAY 94-9027 and published data from one efmoroctocog alfa trial, one BAX 855 trial charges occur for all patients with an Elixhauser'}
# {'Rank': 857, 'Title': 'Effect of oral methylprednisolone on clinical outcomes in patients with IgA nephropathy: the TESTING randomized clinical trial', 'Link': 'https://jamanetwork.com/journals/jama/article-abstract/2646717', 'Abstract': 'Among patients with IgA nephropathy and proteinuria of 1 g/d or greater, oral  conclusions about treatment benefit cannot be made, owing to early termination of the trial.'}
# {'Rank': 858, 'Title': 'Dupilumab and the risk of conjunctivitis and serious infection in patients with atopic dermatitis: A propensity scorematched cohort study', 'Link': 'https://www.sciencedirect.com/science/article/pii/S0190962220326852', 'Abstract': 'Similarly, the CHRONOS trial found a 1.7- to 2.5-fold increase among 425 patients with AD  First, the use of 1:1 PS matching restricted our analysis to very similar patients, which'}
# {'Rank': 859, 'Title': 'Guest EditorialMatching Patients to Treatments', 'Link': 'https://www.ingentaconnect.com/content/ppa/pr/2014/00002014/00000036/art00002', 'Abstract': 'Matched treatments for each patient subgroup are underpinned by research evidence and expert consensus [12,13]. For patients at low risk, matched  a large randomised trial with 850'}
# {'Rank': 860, 'Title': 'Evaluating MatchingAdjusted Indirect Comparisons in Practice: A Case Study of Patients with AttentionDeficit/Hyperactivity Disorder', 'Link': 'https://onlinelibrary.wiley.com/doi/abs/10.1002/hec.3408', 'Abstract': 'guanfacine sample to patients who completed the trial, were  baseline disease severity as atomoxetine trial participants (ie,  MAIC approach matched mean and variance of all patient'}
# ********************* 86-PAGE SCRAPED !! *********************
# Data has been appended to 'google_scholar_patient_trial_matching_data.csv' in CSV format.
# {'Rank': 861, 'Title': 'Impact of laparoscopic gastrectomy on longterm prognosis of patients with primary T3 or more advanced gastric cancer: A propensity score matching analysis', 'Link': 'https://onlinelibrary.wiley.com/doi/abs/10.1002/ags3.12651', 'Abstract': 'After matching, there were 97 patients in each group, with no significant differences in background characteristics. After matching,  In the CLASS-01 trial, the percentage of postoperative'}
# {'Rank': 862, 'Title': 'Can indirect comparison methods mitigate evolving trial populations in adjunctive antiepileptic drug trials? A propensity-score matched indirect comparison of', 'Link': 'https://www.valueinhealthjournal.com/article/S1098-3015(16)00250-3/abstract', 'Abstract': 'Baseline characteristics of patients with focal seizures recruited into adjunctive AED trials  This analysis used propensity-score matched patient-level data in an indirect comparison of'}
# {'Rank': 863, 'Title': 'Concomitant leflunomide therapy in patients with active rheumatoid arthritis despite stable doses of methotrexate: a randomized, double-blind, placebo-controlled trial', 'Link': 'https://www.acpjournals.org/doi/abs/10.7326/0003-4819-137-9-200211050-00007', 'Abstract': '2 days followed by 10 mg/d or matching placebo. If substantial adverse events occurred,  matching placebo per day was required. If substantial adverse events occurred while the patient'}
# {'Rank': 864, 'Title': 'Dose escalation prophylactic donor lymphocyte infusion after T-cell depleted matched related donor allogeneic hematopoietic cell transplantation is feasible and', 'Link': 'https://www.nature.com/articles/s41409-020-0798-4', 'Abstract': 'trial provides arguing against the use of pDLI in patients who have received MUD allo-SCT. Patients  our trial population, but against similar patients receiving treatment at our center.'}
# {'Rank': 865, 'Title': None, 'Link': None, 'Abstract': ''}
# {'Rank': 866, 'Title': 'in rectal cancer patients treated with preoperative chemoradiation and total mesorectal excision: a multicenter and retrospective propensity-score matching study', 'Link': 'https://www.sciencedirect.com/science/article/pii/S0360301618337957', 'Abstract': 'trial investigated the effect of AC on oncologic outcomes in rectal cancer. In subgroup analysis, this trial  used in the EORTC trial had a poor compliance among patients with rectal cancer'}
# {'Rank': 867, 'Title': 'Sirolimus and mycophenolate mofetil as GVHD prophylaxis in myeloablative, matched-related donor hematopoietic cell transplantation', 'Link': 'https://www.nature.com/articles/bmt2011104', 'Abstract': 'Patients 261 years of age with a diagnosis of high-risk hematological malignancy were eligible; however, at the closure of this trial, there were no pediatric patients enrolled. The'}
# {'Rank': 868, 'Title': 'of left atrial appendage occlusion versus direct oral anticoagulation in patients with atrial fibrillation and prior ischemic stroke: A propensity-score matched', 'Link': 'https://www.sciencedirect.com/science/article/pii/S0167527322010191', 'Abstract': 'AF patients enrolled in the Amulet Observational Study with  -score matched cohort of incident AF patients with prior  AVERROES trial data cannot be extrapolated to patients with'}
# {'Rank': 869, 'Title': 'Transapical aortic valve implantation in 100 consecutive patients: comparison to propensity-matched conventional aortic valve replacement', 'Link': 'https://academic.oup.com/eurheartj/article-abstract/31/11/1398/590461', 'Abstract': 'trial data is available. We therefore believe that our propensity matching study, which resulted in two patient  Although control patients underwent their procedures over a longer time'}
# {'Rank': 870, 'Title': 'Cost of care for patients in cancer clinical trials', 'Link': 'https://academic.oup.com/jnci/article-abstract/92/2/136/2964976', 'Abstract': 'on some patients for as long as 5 years, they found that trial  for 40 patients in breast cancer trials and 28 patients in colon  well as matched analyses of the trial enrollees for whom well-'}
# ********************* 87-PAGE SCRAPED !! *********************
# Data has been appended to 'google_scholar_patient_trial_matching_data.csv' in CSV format.
# {'Rank': 871, 'Title': 'Exposure matching for extrapolation of efficacy in pediatric drug development', 'Link': 'https://accp1.onlinelibrary.wiley.com/doi/abs/10.1002/jcph.744', 'Abstract': 'The main measures were the pediatric PK studies trial design elements and drug systemic  to exposure matching and exposure agreement for adult and pediatric patients as the basis'}
# {'Rank': 872, 'Title': 'Efficacy evaluation of intravenous immunoglobulin in non-severe patients with COVID-19: A retrospective cohort study based on propensity score matching', 'Link': 'https://www.sciencedirect.com/science/article/pii/S1201971221000151', 'Abstract': 'In this study, 45 patients received IVIG therapy and 594 patients received standard therapy.  on hospitalized patients with COVID-19. The Solidarity Trial is an international clinical trial'}
# {'Rank': 873, 'Title': 'outcome and morbidity in the elderly rectal cancer patients after preoperative chemoradiotherapy and total mesorectal excision: a multi-institutional and case-matched', 'Link': 'https://journals.lww.com/annalsofsurgery/fulltext/2019/01000/Oncologic_Outcome_and_Morbidity_in_the_Elderly.23.aspx', 'Abstract': 'The German CAO/ARO/AIO-94 trial enrolled patients under 75 years. The median age of  rectal cancer patients, we classified patients into the 2 groups using propensity-score matching'}
# {'Rank': 874, 'Title': 'of next-generation self-expanding versus balloon-expandable transcatheter aortic valves in patients with small aortic annulus: a multicenter propensity-matched', 'Link': 'https://www.ahajournals.org/doi/abs/10.1161/CIRCINTERVENTIONS.117.005013', 'Abstract': 'PPM occurs less frequently after TAVR but was a relevant predictor of 1-year mortality in the subgroup of patients without PVR in the PARTNER A trial. Because PVR almost'}
# {'Rank': 875, 'Title': 'How to select early-stage cervical cancer patients still suitable for laparoscopic radical hysterectomy: a propensity-matched study', 'Link': 'https://link.springer.com/article/10.1245/s10434-019-08162-5', 'Abstract': 'on early-stage cervical cancer (ECC) patient survival. At the same time, advantages of MIS  Therefore, it is essential to select patients who may benefit from MIS without worsening their'}
# {'Rank': 876, 'Title': 'the outcomes between sorafenib and lenvatinib as the first-line systemic treatment for HBV-associated hepatocellular carcinoma: a propensity score matching', 'Link': 'https://bmcgastroenterol.biomedcentral.com/articles/10.1186/s12876-022-02210-3', 'Abstract': 'In subgroup analysis of the REFLECT trial, patients with HBV etiology tended to have longer  :sorafenib) matching, and finally 44 patients treated with lenvatinib and 88 patients treated'}
# {'Rank': 877, 'Title': 'Matching-Adjusted Indirect Comparisons of Lorlatinib Versus Chemotherapy for Patients With Second-Line or Later Anaplastic Lymphoma KinasePositive', 'Link': 'https://www.sciencedirect.com/science/article/pii/S1098301522020988', 'Abstract': 'in a single-arm trial, we used matching-adjusted indirect  for between-trial differences in baseline patient characteristics in  The baseline patient characteristics included in the matching'}
# {'Rank': 878, 'Title': 'Matching-adjusted indirect treatment comparison of siponimod and other disease modifying treatments in secondary progressive multiple sclerosis', 'Link': 'https://www.tandfonline.com/doi/abs/10.1080/03007995.2020.1747999', 'Abstract': 'Since the target population for siponimod was based on the EXPAND trial, which included only SPMS patients, the scope of the present analysis was defined to capture the available'}
# {'Rank': 879, 'Title': 'Periodontal treatment reduces risk of adverse respiratory events in patients with chronic obstructive pulmonary disease: a propensity-matched cohort study', 'Link': 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4902439/', 'Abstract': 'A recent randomized controlled trial also reported that periodontal therapy for COPD patients with periodontitis can not only improve the pulmonary function but also reduce the'}
# {'Rank': 880, 'Title': 'The impact of digoxin on mortality in patients with chronic systolic heart failure: a propensity-matched cohort study', 'Link': 'https://www.sciencedirect.com/science/article/pii/S016752731633457X', 'Abstract': 'This study calls for a clinical trial probably designed as a withdrawal study in the presence of use of guideline-directed medical therapy. In addition, we found that the impact of digoxin'}
# ********************* 88-PAGE SCRAPED !! *********************
# Data has been appended to 'google_scholar_patient_trial_matching_data.csv' in CSV format.
# ********************* 89-PAGE SCRAPED !! *********************
# Data has been appended to 'google_scholar_patient_trial_matching_data.csv' in CSV format.
# ********************* 90-PAGE SCRAPED !! *********************
# Data has been appended to 'google_scholar_patient_trial_matching_data.csv' in CSV format.
# ********************* 91-PAGE SCRAPED !! *********************
# Data has been appended to 'google_scholar_patient_trial_matching_data.csv' in CSV format.
# ********************* 92-PAGE SCRAPED !! *********************
# Data has been appended to 'google_scholar_patient_trial_matching_data.csv' in CSV format.
# ********************* 93-PAGE SCRAPED !! *********************
# Data has been appended to 'google_scholar_patient_trial_matching_data.csv' in CSV format.
# ********************* 94-PAGE SCRAPED !! *********************
# Data has been appended to 'google_scholar_patient_trial_matching_data.csv' in CSV format.
# ********************* 95-PAGE SCRAPED !! *********************
# Data has been appended to 'google_scholar_patient_trial_matching_data.csv' in CSV format.
# ********************* 96-PAGE SCRAPED !! *********************
# Data has been appended to 'google_scholar_patient_trial_matching_data.csv' in CSV format.
# ********************* 97-PAGE SCRAPED !! *********************
# Data has been appended to 'google_scholar_patient_trial_matching_data.csv' in CSV format.
# ********************* 98-PAGE SCRAPED !! *********************
# Data has been appended to 'google_scholar_patient_trial_matching_data.csv' in CSV format.
# ********************* 99-PAGE SCRAPED !! *********************
# Data has been appended to 'google_scholar_patient_trial_matching_data.csv' in CSV format.
# ********************* 100-PAGE SCRAPED !! *********************
# Data has been appended to 'google_scholar_patient_trial_matching_data.csv' in CSV format.
# ********************* 101-PAGE SCRAPED !! *********************
# Data has been appended to 'google_scholar_patient_trial_matching_data.csv' in CSV format.
# ********************* 102-PAGE SCRAPED !! *********************
# Data has been appended to 'google_scholar_patient_trial_matching_data.csv' in CSV format.
